# %%
import numpy as np, pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from itertools import islice
from pymongo import MongoClient
import re
import pickle

# %%
def combine_two_graphs():
    edges_time = pd.read_csv("../Data/graphs/time_based_graph.csv")
    edges_time = edges_time[["from","to", "count"]]
    edges_time = edges_time.rename(columns = {"count":"median_time"})
    edges_frequency = pd.read_csv("../Data/graphs/highest_frequency.csv")
    edges_frequency = edges_frequency[["from","to", "count"]]
    
    edges_time.dropna(inplace = True)
    edges_frequency.dropna(inplace = True)
    combined_df = pd.merge(edges_frequency, edges_time, how='inner', on=['from', 'to'])
    combined_df["median_time"] =  combined_df["median_time"].apply(lambda x: x if x>0 else 1)
    combined_df["weight1"] = combined_df["median_time"]/combined_df["count"]
    return combined_df

# %%
def create_graphs(combined_df, using=None):
    if using == "most_common":
        edges = [(combined_df.loc[i, "from"], combined_df.loc[i, "to"],
                  combined_df.loc[i, "count"]) for i in range(combined_df.shape[0])]
    elif using == "shortest_time":
        edges = [(combined_df.loc[i, "from"], combined_df.loc[i, "to"],
                  combined_df.loc[i, "median_time"]) for i in range(combined_df.shape[0])]
    elif using == "min_transitions":
        edges = [(combined_df.loc[i, "from"], combined_df.loc[i, "to"], 1)
                 for i in range(combined_df.shape[0])]
    else:
        edges = [(combined_df.loc[i, "from"], combined_df.loc[i, "to"],
                  combined_df.loc[i, "weight1"]) for i in range(combined_df.shape[0])]

    g = nx.graph.Graph()
    g.add_weighted_edges_from(edges)
    return g

# %%
def save_graph(): 
    combined_df = combine_two_graphs()
    for g in ["most_common", "shortest_time", "min_transitions", "combination"]:
        graph = create_graphs(combined_df, g)
        print(graph.nodes())
        nx.write_gpickle(graph, '../Data/graphs/final_graphs/'+g+'.gpickle')

# %%
save_graph()
# Out:
# ['senior engineer', 'lead engineer', 'director of engineering', 'project manager', 'vp of engineering', 'in government', 'assist the director of human resources', 'bachelor of arts in mass communications', 'technical recruiter', 'bachelor of science in personal assistant', 'marketing director', 'manager', 'diploma in general science', 'process engineer', 'phd in environmental engineering', 'director of software engineering', 'engineer', 'manager of software engineering', 'software engineer', 'bachelors of science in architecture', 'architect intern ', 'master in architecture', 'architect inspector', 'architect', 'architect intern', 'bachelor of arts in finance', 'lead operation analyst', 'associate of science in business administration', 'bachelor in economics', 'master in public administration', 'business analyst', 'auditor', 'b.e in network engineering in network engineering', 'bachelor of science in marketing and bsiness administration', 'financial analyst i', 'senior financial analyst', 'bachelor of science in international stdies in international stdies', 'msc in compter science', 'supervisor of engineering', 'engineering project manager', 'bachelor of science in aerospace engineering', 'aerospace engineer', 'sr. project engineer gas engines', 'sr. software engineer\\/ architect\\/sme', 'sr. software engineer \\/ architect', 'certificate in compter programming', 'associate of science in medical assistant', 'recruiter', 'bachelors in compter science in information technology', 'director product development', 'phd in physical chemistry', 'data scientist', 'master in human resource management', 'director', 'in training', 'human resource associate', 'software development engineer', 'senior software architect', 'master in bsiness administration', 'engineering intern', 'bachelor of science in chemical engineering', 'bachelor of science in engineering science', 'bachelor of science in mechanical engineering', 'bachelor of science in civil engineering in fndamentals of engineering exam', 'bachelor of science in physics', 'bachelor in human resource management', 'associates in cosmetology', 'b.s. in compter science', 'programmer analyst', 'master in nonprofit administration', 'master in paralegal studies', 'bachelor of science in economics', 'master of science in statistics', 'master in engineering management', 'operations analyst', 'bachelor of arts in english', 'high school diploma', 'sales', 'sales director', 'bachelor of science in indstrial engineering', 'phd in physics', 'bachelor of arts', 'operation analyst intern', 'vp of marketing', 'postdoc research associate', 'senior software engineer', 'm.s. in compter science in science and engineering', 'vp of software', 'data architect', 'm.s. in information systems', 'software architect', 'senior architect', 'certificate of advanced studies in information technology', 'bachelor in commerce', 'bachelor of science in b.a. in marketing', 'marketing director & founder', 'communications director', 'bachelor of arts in political science', 'b.s. in physics', 'nursing recruiter', 'college recruiter', 'onsite technical recruiter', 'corporate recruiter', 'software engineer intern', 'm.s in compter science in compter science', 'master of science in electrical engineering', 'production trainee (operation analyst)', 'bachelor of engineering in mechanical engineering', 'master in engineering', 'data analyst', 'business analyst intern', 'master of science in information systems', 'bachelor of arts in mass commnications in pblic relations', 'corporate director of operations', 'vp of operations', 'phd in electrical engineering', 'bachelor of information technology in information technology', 'masters in compter science', 'bachelors in commerce', 'diploma in financial analysis', 'bachelor of science in music', 'associate product manager', 'certificate in paralegal', 'certificate in web design', 'masters in architecture', 'senior electromechanical engineer', 'senior engineer manager', 'senior vp of ...
# ['senior engineer', 'lead engineer', 'director of engineering', 'project manager', 'vp of engineering', 'in government', 'assist the director of human resources', 'bachelor of arts in mass communications', 'technical recruiter', 'bachelor of science in personal assistant', 'marketing director', 'manager', 'diploma in general science', 'process engineer', 'phd in environmental engineering', 'director of software engineering', 'engineer', 'manager of software engineering', 'software engineer', 'bachelors of science in architecture', 'architect intern ', 'master in architecture', 'architect inspector', 'architect', 'architect intern', 'bachelor of arts in finance', 'lead operation analyst', 'associate of science in business administration', 'bachelor in economics', 'master in public administration', 'business analyst', 'auditor', 'b.e in network engineering in network engineering', 'bachelor of science in marketing and bsiness administration', 'financial analyst i', 'senior financial analyst', 'bachelor of science in international stdies in international stdies', 'msc in compter science', 'supervisor of engineering', 'engineering project manager', 'bachelor of science in aerospace engineering', 'aerospace engineer', 'sr. project engineer gas engines', 'sr. software engineer\\/ architect\\/sme', 'sr. software engineer \\/ architect', 'certificate in compter programming', 'associate of science in medical assistant', 'recruiter', 'bachelors in compter science in information technology', 'director product development', 'phd in physical chemistry', 'data scientist', 'master in human resource management', 'director', 'in training', 'human resource associate', 'software development engineer', 'senior software architect', 'master in bsiness administration', 'engineering intern', 'bachelor of science in chemical engineering', 'bachelor of science in engineering science', 'bachelor of science in mechanical engineering', 'bachelor of science in civil engineering in fndamentals of engineering exam', 'bachelor of science in physics', 'bachelor in human resource management', 'associates in cosmetology', 'b.s. in compter science', 'programmer analyst', 'master in nonprofit administration', 'master in paralegal studies', 'bachelor of science in economics', 'master of science in statistics', 'master in engineering management', 'operations analyst', 'bachelor of arts in english', 'high school diploma', 'sales', 'sales director', 'bachelor of science in indstrial engineering', 'phd in physics', 'bachelor of arts', 'operation analyst intern', 'vp of marketing', 'postdoc research associate', 'senior software engineer', 'm.s. in compter science in science and engineering', 'vp of software', 'data architect', 'm.s. in information systems', 'software architect', 'senior architect', 'certificate of advanced studies in information technology', 'bachelor in commerce', 'bachelor of science in b.a. in marketing', 'marketing director & founder', 'communications director', 'bachelor of arts in political science', 'b.s. in physics', 'nursing recruiter', 'college recruiter', 'onsite technical recruiter', 'corporate recruiter', 'software engineer intern', 'm.s in compter science in compter science', 'master of science in electrical engineering', 'production trainee (operation analyst)', 'bachelor of engineering in mechanical engineering', 'master in engineering', 'data analyst', 'business analyst intern', 'master of science in information systems', 'bachelor of arts in mass commnications in pblic relations', 'corporate director of operations', 'vp of operations', 'phd in electrical engineering', 'bachelor of information technology in information technology', 'masters in compter science', 'bachelors in commerce', 'diploma in financial analysis', 'bachelor of science in music', 'associate product manager', 'certificate in paralegal', 'certificate in web design', 'masters in architecture', 'senior electromechanical engineer', 'senior engineer manager', 'senior vp of ...
# ['senior engineer', 'lead engineer', 'director of engineering', 'project manager', 'vp of engineering', 'in government', 'assist the director of human resources', 'bachelor of arts in mass communications', 'technical recruiter', 'bachelor of science in personal assistant', 'marketing director', 'manager', 'diploma in general science', 'process engineer', 'phd in environmental engineering', 'director of software engineering', 'engineer', 'manager of software engineering', 'software engineer', 'bachelors of science in architecture', 'architect intern ', 'master in architecture', 'architect inspector', 'architect', 'architect intern', 'bachelor of arts in finance', 'lead operation analyst', 'associate of science in business administration', 'bachelor in economics', 'master in public administration', 'business analyst', 'auditor', 'b.e in network engineering in network engineering', 'bachelor of science in marketing and bsiness administration', 'financial analyst i', 'senior financial analyst', 'bachelor of science in international stdies in international stdies', 'msc in compter science', 'supervisor of engineering', 'engineering project manager', 'bachelor of science in aerospace engineering', 'aerospace engineer', 'sr. project engineer gas engines', 'sr. software engineer\\/ architect\\/sme', 'sr. software engineer \\/ architect', 'certificate in compter programming', 'associate of science in medical assistant', 'recruiter', 'bachelors in compter science in information technology', 'director product development', 'phd in physical chemistry', 'data scientist', 'master in human resource management', 'director', 'in training', 'human resource associate', 'software development engineer', 'senior software architect', 'master in bsiness administration', 'engineering intern', 'bachelor of science in chemical engineering', 'bachelor of science in engineering science', 'bachelor of science in mechanical engineering', 'bachelor of science in civil engineering in fndamentals of engineering exam', 'bachelor of science in physics', 'bachelor in human resource management', 'associates in cosmetology', 'b.s. in compter science', 'programmer analyst', 'master in nonprofit administration', 'master in paralegal studies', 'bachelor of science in economics', 'master of science in statistics', 'master in engineering management', 'operations analyst', 'bachelor of arts in english', 'high school diploma', 'sales', 'sales director', 'bachelor of science in indstrial engineering', 'phd in physics', 'bachelor of arts', 'operation analyst intern', 'vp of marketing', 'postdoc research associate', 'senior software engineer', 'm.s. in compter science in science and engineering', 'vp of software', 'data architect', 'm.s. in information systems', 'software architect', 'senior architect', 'certificate of advanced studies in information technology', 'bachelor in commerce', 'bachelor of science in b.a. in marketing', 'marketing director & founder', 'communications director', 'bachelor of arts in political science', 'b.s. in physics', 'nursing recruiter', 'college recruiter', 'onsite technical recruiter', 'corporate recruiter', 'software engineer intern', 'm.s in compter science in compter science', 'master of science in electrical engineering', 'production trainee (operation analyst)', 'bachelor of engineering in mechanical engineering', 'master in engineering', 'data analyst', 'business analyst intern', 'master of science in information systems', 'bachelor of arts in mass commnications in pblic relations', 'corporate director of operations', 'vp of operations', 'phd in electrical engineering', 'bachelor of information technology in information technology', 'masters in compter science', 'bachelors in commerce', 'diploma in financial analysis', 'bachelor of science in music', 'associate product manager', 'certificate in paralegal', 'certificate in web design', 'masters in architecture', 'senior electromechanical engineer', 'senior engineer manager', 'senior vp of ...
# ['senior engineer', 'lead engineer', 'director of engineering', 'project manager', 'vp of engineering', 'in government', 'assist the director of human resources', 'bachelor of arts in mass communications', 'technical recruiter', 'bachelor of science in personal assistant', 'marketing director', 'manager', 'diploma in general science', 'process engineer', 'phd in environmental engineering', 'director of software engineering', 'engineer', 'manager of software engineering', 'software engineer', 'bachelors of science in architecture', 'architect intern ', 'master in architecture', 'architect inspector', 'architect', 'architect intern', 'bachelor of arts in finance', 'lead operation analyst', 'associate of science in business administration', 'bachelor in economics', 'master in public administration', 'business analyst', 'auditor', 'b.e in network engineering in network engineering', 'bachelor of science in marketing and bsiness administration', 'financial analyst i', 'senior financial analyst', 'bachelor of science in international stdies in international stdies', 'msc in compter science', 'supervisor of engineering', 'engineering project manager', 'bachelor of science in aerospace engineering', 'aerospace engineer', 'sr. project engineer gas engines', 'sr. software engineer\\/ architect\\/sme', 'sr. software engineer \\/ architect', 'certificate in compter programming', 'associate of science in medical assistant', 'recruiter', 'bachelors in compter science in information technology', 'director product development', 'phd in physical chemistry', 'data scientist', 'master in human resource management', 'director', 'in training', 'human resource associate', 'software development engineer', 'senior software architect', 'master in bsiness administration', 'engineering intern', 'bachelor of science in chemical engineering', 'bachelor of science in engineering science', 'bachelor of science in mechanical engineering', 'bachelor of science in civil engineering in fndamentals of engineering exam', 'bachelor of science in physics', 'bachelor in human resource management', 'associates in cosmetology', 'b.s. in compter science', 'programmer analyst', 'master in nonprofit administration', 'master in paralegal studies', 'bachelor of science in economics', 'master of science in statistics', 'master in engineering management', 'operations analyst', 'bachelor of arts in english', 'high school diploma', 'sales', 'sales director', 'bachelor of science in indstrial engineering', 'phd in physics', 'bachelor of arts', 'operation analyst intern', 'vp of marketing', 'postdoc research associate', 'senior software engineer', 'm.s. in compter science in science and engineering', 'vp of software', 'data architect', 'm.s. in information systems', 'software architect', 'senior architect', 'certificate of advanced studies in information technology', 'bachelor in commerce', 'bachelor of science in b.a. in marketing', 'marketing director & founder', 'communications director', 'bachelor of arts in political science', 'b.s. in physics', 'nursing recruiter', 'college recruiter', 'onsite technical recruiter', 'corporate recruiter', 'software engineer intern', 'm.s in compter science in compter science', 'master of science in electrical engineering', 'production trainee (operation analyst)', 'bachelor of engineering in mechanical engineering', 'master in engineering', 'data analyst', 'business analyst intern', 'master of science in information systems', 'bachelor of arts in mass commnications in pblic relations', 'corporate director of operations', 'vp of operations', 'phd in electrical engineering', 'bachelor of information technology in information technology', 'masters in compter science', 'bachelors in commerce', 'diploma in financial analysis', 'bachelor of science in music', 'associate product manager', 'certificate in paralegal', 'certificate in web design', 'masters in architecture', 'senior electromechanical engineer', 'senior engineer manager', 'senior vp of ...

# %%
g = nx.read_gpickle('../Data/graphs/final_graphs/combination.gpickle')

# %%
g.nodes()
# Out:
# ['senior engineer',
#  'lead engineer',
#  'director of engineering',
#  'project manager',
#  'vp of engineering',
#  'in government',
#  'assist the director of human resources',
#  'bachelor of arts in mass communications',
#  'technical recruiter',
#  'bachelor of science in personal assistant',
#  'marketing director',
#  'manager',
#  'diploma in general science',
#  'process engineer',
#  'phd in environmental engineering',
#  'director of software engineering',
#  'engineer',
#  'manager of software engineering',
#  'software engineer',
#  'bachelors of science in architecture',
#  'architect intern ',
#  'master in architecture',
#  'architect inspector',
#  'architect',
#  'architect intern',
#  'bachelor of arts in finance',
#  'lead operation analyst',
#  'associate of science in business administration',
#  'bachelor in economics',
#  'master in public administration',
#  'business analyst',
#  'auditor',
#  'b.e in network engineering in network engineering',
#  'bachelor of science in marketing and bsiness administration',
#  'financial analyst i',
#  'senior financial analyst',
#  'bachelor of science in international stdies in international stdies',
#  'msc in compter science',
#  'supervisor of engineering',
#  'engineering project manager',
#  'bachelor of science in aerospace engineering',
#  'aerospace engineer',
#  'sr. project engineer gas engines',
#  'sr. software engineer\\/ architect\\/sme',
#  'sr. software engineer \\/ architect',
#  'certificate in compter programming',
#  'associate of science in medical assistant',
#  'recruiter',
#  'bachelors in compter science in information technology',
#  'director product development',
#  'phd in physical chemistry',
#  'data scientist',
#  'master in human resource management',
#  'director',
#  'in training',
#  'human resource associate',
#  'software development engineer',
#  'senior software architect',
#  'master in bsiness administration',
#  'engineering intern',
#  'bachelor of science in chemical engineering',
#  'bachelor of science in engineering science',
#  'bachelor of science in mechanical engineering',
#  'bachelor of science in civil engineering in fndamentals of engineering exam',
#  'bachelor of science in physics',
#  'bachelor in human resource management',
#  'associates in cosmetology',
#  'b.s. in compter science',
#  'programmer analyst',
#  'master in nonprofit administration',
#  'master in paralegal studies',
#  'bachelor of science in economics',
#  'master of science in statistics',
#  'master in engineering management',
#  'operations analyst',
#  'bachelor of arts in english',
#  'high school diploma',
#  'sales',
#  'sales director',
#  'bachelor of science in indstrial engineering',
#  'phd in physics',
#  'bachelor of arts',
#  'operation analyst intern',
#  'vp of marketing',
#  'postdoc research associate',
#  'senior software engineer',
#  'm.s. in compter science in science and engineering',
#  'vp of software',
#  'data architect',
#  'm.s. in information systems',
#  'software architect',
#  'senior architect',
#  'certificate of advanced studies in information technology',
#  'bachelor in commerce',
#  'bachelor of science in b.a. in marketing',
#  'marketing director & founder',
#  'communications director',
#  'bachelor of arts in political science',
#  'b.s. in physics',
#  'nursing recruiter',
#  'college recruiter',
#  'onsite technical recruiter',
#  'corporate recruiter',
#  'software engineer intern',
#  'm.s in compter science in compter science',
#  'master of science in electrical engineering',
#  'production trainee (operation analyst)',
#  'bachelor of engineering in mechanical engineering',
#  'master in engineering',
#  'data analyst',
#  'business analyst intern',
#  'master of science in information systems',
#  'bachelor of arts in mass commnications in pblic relations',
#  'corporate director of operations',
#  'vp of operations',
#  'phd in electrical engineering',
#  'bachelor of information technology in information technology',
#  'masters in compter science',
#  'bachelors in commerce',
#  'diploma in financial analysis',
#  'bachelor of science in music',
#  'associate product manager',
#  'certificate in paralegal',
#  'certificate in web design',
#  'masters in architecture',
#  'senior electromechanical engineer',
#  'senior engineer manager',
#  'senior vp of operations',
#  'senior director of operations',
#  'hr director',
#  'bachelor of science in organizational leadership',
#  'master of science in organizational leadership',
#  'operation analyst',
#  'product analyst',
#  'bachelor of arts in business management',
#  'bachelor of arts in business administration',
#  'master of arts in political economy',
#  'bachelor of science in manufacturing technology',
#  'industrial engineering manager',
#  'masters of bsiness administration in bsiness administration',
#  'data engineer',
#  'senior data architect',
#  'chief technology officer',
#  'bachelor of science in accounting',
#  'senior auditor',
#  'assistant auditor',
#  'assistant financial analyst',
#  'master in business administration',
#  'finance analyst',
#  'finance director',
#  'engineering designer',
#  'b.s. in civil engineering',
#  'project engineer',
#  'market research analyst',
#  'bachelor of arts in english literatre',
#  'bachelor of science in marketing',
#  'director of operations',
#  'master of science in engineering',
#  'income processing associate',
#  'bachelor of science in business administration in concentration in accounting',
#  'b.s. in compter engineering',
#  'bachelor in accounting',
#  'certificate in united states air force',
#  'b.s. in information and compter science',
#  'senior software analyst',
#  'university relations recruiter',
#  'master of science in compter science',
#  'bachelor of science in business merchandising',
#  'architectural designer',
#  'bachelor of arts in architecture',
#  'engineering technician intern',
#  'diploma in civil engineering',
#  'activity director & marketing',
#  'director of product management',
#  'systems analyst',
#  'master in acconting and finance',
#  'director of software development',
#  'financial analyst',
#  'b.e. in electronics and telecommunication',
#  'master in compter engineering in compter engineering',
#  'engineering llc - annapolis',
#  'master of science in information technology and management',
#  'data analyst - compliance',
#  'associate product manager | product owner',
#  'b.s. in compter science and engineering',
#  'engineer manager',
#  'project analyst',
#  'bachelor of arts in communications',
#  'director of client strategy',
#  'digital director',
#  'bachelor of arts in crime',
#  'master of science in chemical engineering',
#  'master in economics',
#  'bachelor of science',
#  'development director',
#  'master of science in electrical engineering in electrical engineering',
#  'bachelor of science in applied mathematics',
#  'master of science in financial engineering',
#  'regional director',
#  'master of science in computer science',
#  'senior engineering manager',
#  'corse certificate in landscape design of gardens.',
#  'bachelor of science in biotechnology',
#  'hs diploma',
#  'master of bsiness administration in bsiness administration',
#  'corse certificate in nero-lingistic sales programming (nlsp).',
#  'corse certificate in qality management systems and training of internal aditors (iso 9001).',
#  'bachelor of software engineering in business administration',
#  'master of science in global spply chain',
#  'sr. business intelligent architect',
#  'sr. sql data architect',
#  'bachelor of science in compter information systems',
#  'bachelor of science in graphic design',
#  'bachelor of science in liberal arts',
#  'bachelor in counseling education',
#  'master of science in finance',
#  'bachelor  in accounting',
#  'b.e in electronics and commnications engineering',
#  'm.s in mechanical engineering',
#  'bachelor of science in pblic administration',
#  'budget analyst',
#  'founder',
#  'senior data scientist',
#  'bachelor of science in corporate finance',
#  'master of science in financial mathematics',
#  'system group',
#  'ph.d. in compter science',
#  'corses in compter science',
#  'masters',
#  'senior systems analyst',
#  'bachelor of science in engineering',
#  'system analyst',
#  'business analyst | product owner',
#  'ms in electrical engineering in compter science',
#  'diploma in compter networking',
#  'bachelor of science in accountancy',
#  'senior recruiter (virtual)',
#  'certification',
#  'senior associate engineer',
#  'principal architect',
#  'sr. engineer \\/ mechanical design supervisor',
#  'electrical engineering supervisor',
#  'bachelor of science in advertising and psychology',
#  'bachelor in communications',
#  'director of materials\\/operations',
#  'pd in compter science & systems management',
#  'associate in information technology',
#  'bachelor in business administration',
#  'master of business administration',
#  'financial analyst intern',
#  'bachelor of business administration',
#  'capital control analyst (consultant)',
#  'associate in bsiness',
#  'associate',
#  'commnications',
#  'master of science in predictive analytics',
#  'master in compter science',
#  'bachelor of science in business administration',
#  'master in accounting',
#  'certificate in integrated marketing commnications',
#  'bachelor of bsiness administration in management information systems',
#  'diploma in graphics arts offset printing',
#  'marketing & it director',
#  'certificate in data science',
#  'internal auditor',
#  'bachelor in commnity engagement and education',
#  'recruiter\\/business development',
#  'recruiter\\/talent acquisition partner',
#  'bachelor of arts in operational business management',
#  'bachelor of arts in human resource management',
#  'bachelor in organizational management',
#  'international business development recruiter',
#  'master of science in organizational leadership and qality',
#  'quality manager',
#  'principal scientist',
#  'principal data scientist',
#  'quality engineering technician',
#  'quality engineering team leader',
#  'master in statistics',
#  'bachelor of science in computer science',
#  'senior research scientist',
#  'm.s. in electrical engineering',
#  'diploma in dental assistant',
#  'sales associate\\/closer',
#  'bachelors in bsiness marketing',
#  'bachelor of science in mathematics',
#  'master of compter applications in compter applications',
#  'b.s. in chemical engineering',
#  'm.s. in chemical engineering',
#  'external auditor',
#  'customer service associate',
#  'security analyst',
#  'master of science in accounting',
#  'm.s. in compter engineering',
#  'diploma in stationary engineering',
#  'human resources analyst',
#  'masters in construction management',
#  'consultant architect',
#  'project architect',
#  'revenue analyst',
#  'mba in bsiness',
#  'in digital media',
#  'bachelor of science in electronic engineering',
#  'junior business analyst',
#  'masters in accounting',
#  'bachelor of science in intelligence science and technology',
#  'product manager\\/data analyst',
#  'b.s. in commnity development',
#  'b.s. in political science',
#  'master of computer applications in computer applications',
#  'bachelor of science in management',
#  'associate engineer',
#  'master of science in medical sciences',
#  'm.s. in civil engineering in edcation',
#  'm.s. in applied mathematics in applied mathematics',
#  'master in business management',
#  'senior corporate recruiter',
#  'bachelor of arts international relations',
#  'master of science in business analytics',
#  'lead data architect; csc (dhs',
#  'senior enterprise\\/solution architect',
#  'm.s. in cybersecrity and information assrance',
#  'sr. solutions architect',
#  'sr. software engineer',
#  'associate in arts in liberal arts & sciences',
#  'sales operation administration analyst',
#  'supply chain management operations analyst',
#  'sr. software engineer (consultant)',
#  'diploma in technology',
#  'diploma in marketing',
#  'master of science in logistics management',
#  'm.b.a. in marketing',
#  'bachelor in healthcare management',
#  'master of science in industrial engineering',
#  'bachelor of science in civil engineering',
#  'sales engineer',
#  'master of science in civil engineering',
#  'master in behavioral psychology',
#  'program director',
#  'senior project manager',
#  'diploma in mechanical engineering',
#  'bachelor in vehicle engineering',
#  'bachelor in engineering',
#  'bachelor of arts in sports management in sports management',
#  'bachelor of compter science in tools and technologies',
#  'bachelor of business administration in business development and management',
#  'master of business administration in business administration',
#  'master of science in information technology',
#  'bachelor of arts in history',
#  'diploma in telecommunications',
#  'b.s in commnications',
#  'master of science in applied economics and finance',
#  'actuarial analyst',
#  'assistant finance director',
#  'bachelor of science in ntrition and business logistics',
#  'bachelor of science in electronics engineering',
#  'sourcing recruiter\\/team lead',
#  'vice president engineering & operations',
#  'license in cosmetology',
#  'customer engagement analyst',
#  'diploma in cad',
#  'technician',
#  'bachelor of arts in psychology',
#  'm.s. in compter science',
#  'ph.d. in comptational chemistry',
#  'diploma in bsiness',
#  'diploma in bsiness leadership',
#  'bachelor of science in economics and mathematics',
#  'bachelor of science in psychology',
#  'and prepared board of director materials.',
#  'associate in business administration',
#  'certificate in digital marketing',
#  'preparation and evalation of projects.',
#  'supervisor of agricultural engineering projects',
#  'process engineer intern',
#  'bsc. in process engineering',
#  'bachelor of technology in compters',
#  'bachelor of science in fashion merchandising management & prodct development',
#  'retirement operation analyst',
#  'sr. director of production operations',
#  'masters of science degree in compter science',
#  'master of science in management information systems',
#  'master of science in software engineering',
#  'master of science in information systems in (msis)',
#  'sr. software engineer\\/ architect',
#  'm.s. in information technology and management',
#  'ms in compter science in data mining and pattern recognition',
#  'master of arts in philosophy',
#  'm.ed. in edcational technology',
#  'research analyst',
#  'design engineer',
#  'bachelor of science in political',
#  'bachelor of arts in chemistry',
#  'phd in atmospheric physical chemistry',
#  'bachelor of business administration in grad date',
#  'in criminal jstice',
#  'bachelor of business administration in finance',
#  'certificate in electrical systems design',
#  'senior technician',
#  'senior business analyst',
#  'master of science in management',
#  'bachelor of arts in information technology',
#  'master in environmental engineering',
#  'bachelor of arts in comparative literatre',
#  'senior business intelligence analyst',
#  'master of science in information in management',
#  'master of science in biotechnology',
#  'master of science in business in analytics',
#  'entreprenerial bsiness minor',
#  'bachelor of arts in bsiness management leadership in resorces & hospitality management',
#  'master graduate in leadership and relationship building',
#  'current in radiology\\/psychology',
#  'bachelor of science in electrical engineering and information technology',
#  'bachelor of arts in geographic information systems',
#  'securities operation analyst',
#  'master of arts in marketing',
#  'master in counseling',
#  'in social work',
#  'bachelor in sales',
#  'b.s. in chemical and biological engineering',
#  'sr. engineering program manager',
#  'degree in compter electronics technology',
#  'senior recruiter',
#  'bachelor of science in english',
#  'bachelor in information technology',
#  'master in management of technology',
#  'bachelor of technology',
#  'bachelor in teaching',
#  'masters of administration in communications',
#  'sales operations analyst',
#  'financial operation analyst',
#  'senior credit analyst',
#  'master of science in indstrial engineering',
#  'bachelor of science in petroleum engineering',
#  'senior operations analyst',
#  'master in business administration in finance',
#  'masters in business administration',
#  'associate auditor',
#  'bachelor in french horn performance',
#  'master in psychology',
#  'procurement operation analyst',
#  'b.s. in bsiness administration & accontancy',
#  'diploma in science',
#  'bachelors candidate in compter science',
#  'bachelor of arts in sociology',
#  'associates in compter hardware engineering',
#  'bachelor of science in indstrial technology',
#  'm.s. in engineering and information systems',
#  'vp of software engineering',
#  'master of science in compter science in distance edcation',
#  'bachelor in general studies',
#  'bachelors degree in compter science in compter science',
#  'associate in science in bsiness administration in bsiness administration',
#  'exective mba in bsiness',
#  'b.s. in bsiness ed',
#  'bsc. in compter science smma',
#  'master of science in mechanical engineering',
#  'bachelor of bsiness administration in marketing and management',
#  'director of food and nutrition services',
#  'ba in compter science',
#  'carpenter',
#  'compliance analyst',
#  'bachelor of science in finance',
#  'finance manager\\/finance director',
#  'bachelor of arts in applied mathematics in economics',
#  'product management associate',
#  'master of science in integrated marketing & brand management',
#  'bachelor of arts in accounting',
#  'bachelor of science in architecture',
#  'bachelor in psychology',
#  'associates of art in communications in art',
#  'bachelor of arts in marketing',
#  'bachelor of science in actuarial science',
#  'bsn in bsiness commnication',
#  'diploma in religion',
#  'special finance director',
#  'high school in computer science',
#  'product marketing engineering intern',
#  'in medical',
#  'in history',
#  'bachelor of science in chemistry',
#  'bachelor of bsiness administration in finance & marketing',
#  'vp of sales',
#  'bachelor of science in software engineering',
#  'b.e. in electronics',
#  'corse certificate in formlation',
#  'bachelor of science in electrical engineering',
#  'bachelor of science in biomedical engineering',
#  'bachelors in jornalism',
#  'master of science in physics',
#  'master in business administration in hr and marketing',
#  'bachelor of science in hospitality management',
#  'cpa',
#  'financial analyst (consultant)',
#  'bachelor of science in information technology',
#  'bachelor of science in international trade and marketing',
#  'b.s. in bsiness administration',
#  'sales manager',
#  'b.a. in sport management',
#  'associate of science in middle grades',
#  'bachelor of science in business management',
#  'in compter science',
#  'b.e. in electrical & electronics',
#  'product engineer & product manager',
#  'bachelor of arts in natural science',
#  'operations & engineering services',
#  'certificate in social media & online marketing',
#  'bachelor of science in compter engineering in compter engineering',
#  'a.s. in physics and chemistry',
#  'bachelor of arts in american studies']
