# %%
import numpy as np
import pandas as pd

# %%
path = "/Users/nis89mad/data/lending_club/"

# %%
accepted = pd.read_csv(path+'Accepted/2017Q4.csv')
# Out:
# /Users/nis89mad/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns', None)
accepted.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    35000.0      35000.0          35000.0   60 months
# 1  NaN        NaN     6000.0       6000.0           6000.0   36 months
# 2  NaN        NaN    40000.0      40000.0          40000.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   60 months
# 4  NaN        NaN    27000.0      27000.0          27000.0   60 months
#
#   int_rate  installment grade sub_grade             emp_title emp_length  \
# 0   11.99%       778.38     B        B5      Project Manager    < 1 year
# 1    7.35%       186.23     A        A4  Business Development     1 year
# 2    6.08%      1218.33     A        A2         Editor/Writer   < 1 year
# 3   23.88%       286.99     E        E2                   EMT  10+ years
# 4    9.93%       572.75     B        B2        Data Scientist    3 years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
accepted.application_type.value_counts()
# Out:
# Individual    101437
# Joint App      17211
# Name: application_type, dtype: int64

# %%
accepted.shapepe
# Out:
# (118650, 145)

# %%
keep_cols = ['loan_status','loan_amnt', 'term', 'int_rate', 'grade', 'sub_grade', 
             'emp_length','home_ownership', 'annual_inc', 'verification_status', 
             'issue_d', 'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state',
            'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 
             'mths_since_last_delinq', 'mths_since_last_record', 'open_acc', 'pub_rec',
            'revol_bal', 'revol_util', 'total_acc', 'collections_12_mths_ex_med', 
            'mths_since_last_major_derog', 'policy_code', 'application_type', 
             'annual_inc_joint', 'dti_joint', 'verification_status_joint', 
             'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 
             'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il',
             'il_util', 'open_rv_12m', 'open_rv_24m', 
            ]

# %%
accepted.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (31-120 days)', 'Late (16-30 days)',
#        'In Grace Period', 'Charged Off', nan], dtype=object)

# %%
accepted[accepted.loan_status == 'Fully Paid']
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 8       NaN        NaN    25000.0      25000.0          25000.0   60 months
# 28      NaN        NaN    10800.0      10800.0          10800.0   60 months
# 157     NaN        NaN    15000.0      15000.0          15000.0   60 months
# 186     NaN        NaN    21600.0      21600.0          21600.0   60 months
# 223     NaN        NaN     6000.0       6000.0           6000.0   36 months
# 251     NaN        NaN    35000.0      35000.0          35000.0   60 months
# 264     NaN        NaN     5000.0       5000.0           5000.0   36 months
# 314     NaN        NaN     3000.0       3000.0           3000.0   36 months
# 329     NaN        NaN    24000.0      24000.0          24000.0   60 months
# 341     NaN        NaN    20000.0      20000.0          20000.0   60 months
# 440     NaN        NaN     3500.0       3500.0           3500.0   36 months
# ...

# %%
accepted[accepted.loan_status == 'Current']['issue_d'].unique()
# Out:
# array(['Dec-2017', 'Nov-2017', 'Oct-2017'], dtype=object)
