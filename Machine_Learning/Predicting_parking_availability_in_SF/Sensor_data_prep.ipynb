# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier

# %%
path = '/Users/nis89mad/data/ML2_Final/'

# %% [markdown]
# Load train data to get unique street segments

# %%
train = pd.read_csv(path+'train-parking.csv', parse_dates={"datetime" : ["Date", "Time"]})

# %%
train['Dayofweek'] = train.datetime.dt.dayofweek
train['month'] = train.datetime.dt.month
train['hour'] = train.datetime.dt.hour
train['year'] = train.datetime.dt.year
train.drop('datetime', axis =1, inplace=True)

# %%
train['street'] = train['Street']+' @ '+ train['From']+ '|' + train['Street'] + ' @ '+ train['To']
train.drop(['Street','From','To'], axis=1, inplace=True)

# %%
train.head()
# Out:
#    Real.Spots  Street.Length  any_spot  Dayofweek  month  hour  year  \
# 0           4     179.132970         1          1      1    16  2014
# 1           0      52.740210         0          5      1    20  2014
# 2           0      52.517840         0          5      1    20  2014
# 3           0      52.405315         0          5      1    20  2014
# 4           0      52.191193         0          5      1    20  2014
#
#                                               street
# 0  Mission Street @ 25th Street|Mission Street @ ...
# 1  Polk Street @ Ellis Street|Polk Street @ Olive...
# 2  Van Ness Avenue @ Geary Boulevard|Van Ness Ave...
# 3  Van Ness Avenue @ Bush Street|Van Ness Avenue ...
# 4  Van Ness Avenue @ Daniel Burnham Court|Van Nes...

# %%
street_id = train.groupby('street').size().reset_index()
street_id['street_id'] = np.arange(len(street_id))+1
street_id = street_id[['street', 'street_id']]

# %%
street_id.shape
# Out:
# (96, 2)

# %%
street_id.head()
# Out:
#                                               street  street_id
# 0  23rd Street @ Bartlett Street|23rd Street @ Va...          1
# 1  23rd Street @ Mission Street|23rd Street @ Bar...          2
# 2  23rd Street @ Mission Street|23rd Street @ Cap...          3
# 3  23rd Street @ South Van Ness Avenue|23rd Stree...          4
# 4  Battery Street @ California Street|Battery Str...          5

# %% [markdown]
# Get mapping between Block_ids and street segment ids

# %%
# getting a block id for each street
intersections = pd.read_feather('intersections')

# %%
intersections.head()
# Out:
#                                    S_F                            S_T  \
# 0        23rd Street @ Bartlett Street  23rd Street @ Valencia Street
# 1         23rd Street @ Mission Street  23rd Street @ Bartlett Street
# 2         23rd Street @ Mission Street      23rd Street @ Capp Street
# 3  23rd Street @ South Van Ness Avenue      23rd Street @ Capp Street
# 4   Battery Street @ California Street   Battery Street @ Pine Street
#
#                                                intxn  block_id  from_int_lat  \
# 0  23rd Street @ Bartlett Street, San Francisco|2...        33     37.753779
# 1  23rd Street @ Mission Street, San Francisco|23...        33     37.753845
# 2  23rd Street @ Mission Street, San Francisco|23...        32     37.753845
# 3  23rd Street @ South Van Ness Avenue, San Franc...        32     37.753976
# 4  Battery Street @ California Street, San Franci...         1     37.793224
#
#    from_int_lng  to_int_lat  to_int_lng
# 0   -122.419729   37.753707 -122.420836
# 1   -122.418619   37.753779 -122.419729
# 2   -122.418619   37.753912 -122.417529
# 3   -122.416441   37.753912 -122.417529
# 4   -122.399989   37.792263 -122.399797

# %%
intersections['lat'] = (intersections['from_int_lat']+intersections['to_int_lat'])/2
intersections['lng'] = (intersections['from_int_lng']+intersections['to_int_lng'])/2

# %%
intersections.intxn = intersections.intxn.str.replace(", San Francisco", "")
intersections.intxn = intersections.intxn.str.replace(",San Francisco", "")
intersections['street'] = intersections.S_F.str.replace(' @.*$',"")

# %%
intersections['Street_Block'] = intersections['street'] +'_'+intersections['block_id'].astype(str)
intersections = intersections[['Street_Block', 'lat', 'lng', 'intxn']]

# %%
intersections = intersections.merge(street_id, left_on='intxn', right_on='street')
intersections.drop(['street', 'intxn'], axis=1, inplace=True)

# %%
intersections.head()
# Out:
#        Street_Block        lat         lng  street_id
# 0    23rd Street_33  37.753743 -122.420282          1
# 1    23rd Street_33  37.753812 -122.419174          2
# 2    23rd Street_32  37.753879 -122.418074          3
# 3    23rd Street_32  37.753944 -122.416985          4
# 4  Battery Street_1  37.792744 -122.399893          5

# %%
intersections.to_feather('intersections2')

# %% [markdown]
# Preparing sensor data

# %%
# get sensor data
sensorData = pd.read_csv(path+'ParkingSensorData.csv')
# Out:
# /Users/nis89mad/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sensorData.shapea
# Out:
# (7902291, 33)

# %%
sensorData.T
# Out:
#                                   0                     1        \
# BLOCK_ID                            41522                 41524
# STREET_NAME                   FILLMORE ST           FILLMORE ST
# BLOCK_NUM                              22                    24
# STREET_BLOCK             FILLMORE ST 2200      FILLMORE ST 2400
# AREA_TYPE                           Pilot                 Pilot
# PM_DISTRICT_NAME                 Fillmore              Fillmore
# RATE                                  NaN                   NaN
# START_TIME_DT        01-jul-2012 21:00:00  01-jul-2012 22:00:00
# TOTAL_TIME                          61200                 64800
# TOTAL_OCCUPIED_TIME                 35847                 27576
# TOTAL_VACANT_TIME                   25353                 37224
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                          61200                 64800
# NONOP_OCCUPIED_TIME                 35847                 27576
# NONOP_VACANT_TIME                   25353                 37224
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  July                  July
# CAL_YEAR                             2012                  2012
# CAL_DATE                      01-jul-2012           01-jul-2012
# DAY_TYPE                          weekend               weekend
# TIME_OF_DAY                          2100                  2200
#
#                                   2                     3        \
# BLOCK_ID                            50001                 50002
# STREET_NAME                    JACKSON ST            JACKSON ST
# BLOCK_NUM                               1                     2
# STREET_BLOCK               JACKSON ST 100        JACKSON ST 200
# AREA_TYPE                           Pilot                 Pilot
# PM_DISTRICT_NAME                 Downtown              Downtown
# RATE                                  NaN                   NaN
# START_TIME_DT        01-jul-2012 02:00:00  01-jul-2012 08:00:00
# TOTAL_TIME                          79200                 82800
# TOTAL_OCCUPIED_TIME                 39985                 30465
# TOTAL_VACANT_TIME                   39215                 52335
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                          79200                 82800
# NONOP_OCCUPIED_TIME                 39985                 30465
# NONOP_VACANT_TIME                   39215                 52335
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  July                  July
# CAL_YEAR                             2012                  2012
# CAL_DATE                      01-jul-2012           01-jul-2012
# DAY_TYPE                          weekend               weekend
# TIME_OF_DAY                           200                   800
#
#                                   4                     5        \
# BLOCK_ID                            10903                 11003
# STREET_NAME                      09TH AVE              10TH AVE
# BLOCK_NUM                               3                     3
# STREET_BLOCK                 09TH AVE 300          10TH AVE 300
# AREA_TYPE                         Control               Control
# PM_DISTRICT_NAME           Inner Richmond        Inner Richmond
# RATE                                  NaN                   NaN
# START_TIME_DT        01-jul-2012 08:00:00  01-jul-2012 04:00:00
# TOTAL_TIME                          93600                 43200
# TOTAL_OCCUPIED_TIME                 85690                  8220
# TOTAL_VACANT_TIME                    7910                 31380
# TOTAL_UNKNOWN_TIME                      0                  3600
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                          93600                 43200
# NONOP_OCCUPIED_TIME                 85690                  8220
# NONOP_VACANT_TIME                    7910                 31380
# NONOP_UNKNOWN_TIME                      0                  3600
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  July                  July
# CAL_YEAR                             2012                  2012
# CAL_DATE                      01-jul-2012           01-jul-2012
# DAY_TYPE                          weekend               weekend
# TIME_OF_DAY                           800                   400
#
#                                   6                     7        \
# BLOCK_ID                            11428                 33901
# STREET_NAME                      14TH AVE              BERRY ST
# BLOCK_NUM                              28                     1
# STREET_BLOCK                14TH AVE 2800          BERRY ST 100
# AREA_TYPE                         Control                 Pilot
# PM_DISTRICT_NAME              West Portal     South Embarcadero
# RATE                                  NaN                   NaN
# START_TIME_DT        01-jul-2012 10:00:00  01-jul-2012 14:00:00
# TOTAL_TIME                          32400                151200
# TOTAL_OCCUPIED_TIME                 11116                136360
# TOTAL_VACANT_TIME                   21284                 11240
# TOTAL_UNKNOWN_TIME                      0                  3600
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                          32400                151200
# NONOP_OCCUPIED_TIME                 11116                136360
# NONOP_VACANT_TIME                   21284                 11240
# NONOP_UNKNOWN_TIME                      0                  3600
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  July                  July
# CAL_YEAR                             2012                  2012
# CAL_DATE                      01-jul-2012           01-jul-2012
# DAY_TYPE                          weekend               weekend
# TIME_OF_DAY                          1000                  1400
#
#                                   8                     9         ...    \
# BLOCK_ID                            33902                 41531   ...
# STREET_NAME                      BERRY ST           FILLMORE ST   ...
# BLOCK_NUM                               2                    31   ...
# STREET_BLOCK                 BERRY ST 200      FILLMORE ST 3100   ...
# AREA_TYPE                           Pilot                 Pilot   ...
# PM_DISTRICT_NAME        South Embarcadero                Marina   ...
# RATE                                  NaN                   NaN   ...
# START_TIME_DT        01-jul-2012 17:00:00  01-jul-2012 06:00:00   ...
# TOTAL_TIME                          82800                 86400   ...
# TOTAL_OCCUPIED_TIME                 78123                 28290   ...
# TOTAL_VACANT_TIME                    1077                 58110   ...
# TOTAL_UNKNOWN_TIME                   3600                     0   ...
# OP_TIME                                 0                     0   ...
# OP_OCCUPIED_TIME                        0                     0   ...
# OP_VACANT_TIME                          0                     0   ...
# OP_UNKNOWN_TIME                         0                     0   ...
# NONOP_TIME                          82800                 86400   ...
# NONOP_OCCUPIED_TIME                 78123                 28290   ...
# NONOP_VACANT_TIME                    1077                 58110   ...
# NONOP_UNKNOWN_TIME                   3600                     0   ...
# GMP_TIME                                0                     0   ...
# GMP_OCCUPIED_TIME                       0                     0   ...
# GMP_VACANT_TIME                         0                     0   ...
# GMP_UNKNOWN_TIME                        0                     0   ...
# COMM_TIME                               0                     0   ...
# COMM_OCCUPIED_TIME                      0                     0   ...
# COMM_VACANT_TIME                        0                     0   ...
# COMM_UNKNOWN_TIME                       0                     0   ...
# CAL_MONTH_NAME                  July                  July        ...
# CAL_YEAR                             2012                  2012   ...
# CAL_DATE                      01-jul-2012           01-jul-2012   ...
# DAY_TYPE                          weekend               weekend   ...
# TIME_OF_DAY                          1700                   600   ...
#
#                                   7902281               7902282  \
# BLOCK_ID                            33103                 33429
# STREET_NAME                     BRYANT ST           BUCHANAN ST
# BLOCK_NUM                               3                    29
# STREET_BLOCK                BRYANT ST 300      BUCHANAN ST 2900
# AREA_TYPE                           Pilot               Control
# PM_DISTRICT_NAME        South Embarcadero                 Union
# RATE                                  NaN                   NaN
# START_TIME_DT        12-oct-2011 00:00:00  10-oct-2011 18:00:00
# TOTAL_TIME                         122400                 32400
# TOTAL_OCCUPIED_TIME                  7667                 32082
# TOTAL_VACANT_TIME                  114733                   318
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                         122400                 32400
# NONOP_OCCUPIED_TIME                  7667                 32082
# NONOP_VACANT_TIME                  114733                   318
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  October               October
# CAL_YEAR                             2011                  2011
# CAL_DATE                      12-oct-2011           10-oct-2011
# DAY_TYPE                          weekday               weekday
# TIME_OF_DAY                             0                  1800
#
#                                   7902283               7902284  \
# BLOCK_ID                            33429                 33429
# STREET_NAME                   BUCHANAN ST           BUCHANAN ST
# BLOCK_NUM                              29                    29
# STREET_BLOCK             BUCHANAN ST 2900      BUCHANAN ST 2900
# AREA_TYPE                         Control               Control
# PM_DISTRICT_NAME                    Union                 Union
# RATE                                  NaN                   NaN
# START_TIME_DT        12-oct-2011 05:00:00  12-oct-2011 09:00:00
# TOTAL_TIME                          32400                 32400
# TOTAL_OCCUPIED_TIME                     0                 21639
# TOTAL_VACANT_TIME                   32400                 10761
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                                 0                 32400
# OP_OCCUPIED_TIME                        0                 21639
# OP_VACANT_TIME                          0                 10761
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                          32400                     0
# NONOP_OCCUPIED_TIME                     0                     0
# NONOP_VACANT_TIME                   32400                     0
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                                0                 32400
# GMP_OCCUPIED_TIME                       0                 21639
# GMP_VACANT_TIME                         0                 10761
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  October               October
# CAL_YEAR                             2011                  2011
# CAL_DATE                      12-oct-2011           12-oct-2011
# DAY_TYPE                          weekday               weekday
# TIME_OF_DAY                           500                   900
#
#                                   7902285               7902286  \
# BLOCK_ID                            33429                 33418
# STREET_NAME                   BUCHANAN ST           BUCHANAN ST
# BLOCK_NUM                              29                    18
# STREET_BLOCK             BUCHANAN ST 2900      BUCHANAN ST 1800
# AREA_TYPE                         Control                 Pilot
# PM_DISTRICT_NAME                    Union              Fillmore
# RATE                                  NaN                   NaN
# START_TIME_DT        13-oct-2011 14:00:00  16-oct-2011 09:00:00
# TOTAL_TIME                          32400                 43200
# TOTAL_OCCUPIED_TIME                 30775                 35311
# TOTAL_VACANT_TIME                    1625                  7889
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                             32400                     0
# OP_OCCUPIED_TIME                    30775                     0
# OP_VACANT_TIME                       1625                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                              0                 43200
# NONOP_OCCUPIED_TIME                     0                 35311
# NONOP_VACANT_TIME                       0                  7889
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                            32400                     0
# GMP_OCCUPIED_TIME                   30775                     0
# GMP_VACANT_TIME                      1625                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  October               October
# CAL_YEAR                             2011                  2011
# CAL_DATE                      13-oct-2011           16-oct-2011
# DAY_TYPE                          weekday               weekend
# TIME_OF_DAY                          1400                   900
#
#                                   7902287               7902288  \
# BLOCK_ID                            33003                 33103
# STREET_NAME                    BRANNAN ST             BRYANT ST
# BLOCK_NUM                               3                     3
# STREET_BLOCK               BRANNAN ST 300         BRYANT ST 300
# AREA_TYPE                           Pilot                 Pilot
# PM_DISTRICT_NAME        South Embarcadero     South Embarcadero
# RATE                                  NaN                   NaN
# START_TIME_DT        20-oct-2011 19:00:00  30-oct-2011 08:00:00
# TOTAL_TIME                         201600                122400
# TOTAL_OCCUPIED_TIME                189141                 11331
# TOTAL_VACANT_TIME                   12459                111069
# TOTAL_UNKNOWN_TIME                      0                     0
# OP_TIME                                 0                     0
# OP_OCCUPIED_TIME                        0                     0
# OP_VACANT_TIME                          0                     0
# OP_UNKNOWN_TIME                         0                     0
# NONOP_TIME                         201600                122400
# NONOP_OCCUPIED_TIME                189141                 11331
# NONOP_VACANT_TIME                   12459                111069
# NONOP_UNKNOWN_TIME                      0                     0
# GMP_TIME                                0                     0
# GMP_OCCUPIED_TIME                       0                     0
# GMP_VACANT_TIME                         0                     0
# GMP_UNKNOWN_TIME                        0                     0
# COMM_TIME                               0                     0
# COMM_OCCUPIED_TIME                      0                     0
# COMM_VACANT_TIME                        0                     0
# COMM_UNKNOWN_TIME                       0                     0
# CAL_MONTH_NAME                  October               October
# CAL_YEAR                             2011                  2011
# CAL_DATE                      20-oct-2011           30-oct-2011
# DAY_TYPE                          weekday               weekend
# TIME_OF_DAY                          1900                   800
#
#                                   7902289 7902290
# BLOCK_ID                            33103
# STREET_NAME                     BRYANT ST     NaN
# BLOCK_NUM                               3     NaN
# STREET_BLOCK                BRYANT ST 300     NaN
# AREA_TYPE                           Pilot     NaN
# PM_DISTRICT_NAME        South Embarcadero     NaN
# RATE                                  NaN     NaN
# START_TIME_DT        30-oct-2011 11:00:00     NaN
# TOTAL_TIME                         122400     NaN
# TOTAL_OCCUPIED_TIME                 25912     NaN
# TOTAL_VACANT_TIME                   96488     NaN
# TOTAL_UNKNOWN_TIME                      0     NaN
# OP_TIME                                 0     NaN
# OP_OCCUPIED_TIME                        0     NaN
# OP_VACANT_TIME                          0     NaN
# OP_UNKNOWN_TIME                         0     NaN
# NONOP_TIME                         122400     NaN
# NONOP_OCCUPIED_TIME                 25912     NaN
# NONOP_VACANT_TIME                   96488     NaN
# NONOP_UNKNOWN_TIME                      0     NaN
# GMP_TIME                                0     NaN
# GMP_OCCUPIED_TIME                       0     NaN
# GMP_VACANT_TIME                         0     NaN
# GMP_UNKNOWN_TIME                        0     NaN
# COMM_TIME                               0     NaN
# COMM_OCCUPIED_TIME                      0     NaN
# COMM_VACANT_TIME                        0     NaN
# COMM_UNKNOWN_TIME                       0     NaN
# CAL_MONTH_NAME                  October       NaN
# CAL_YEAR                             2011     NaN
# CAL_DATE                      30-oct-2011     NaN
# DAY_TYPE                          weekend     NaN
# TIME_OF_DAY                          1100     NaN
#
# [33 rows x 7902291 columns]

# %%
# filter out unwanted columns
cols= ['STREET_NAME', 'BLOCK_NUM', 'TOTAL_TIME', 'TOTAL_OCCUPIED_TIME', 'START_TIME_DT']
sensorData = sensorData[cols]

# %%
sensorData.head()
# Out:
#    STREET_NAME  BLOCK_NUM  TOTAL_TIME  TOTAL_OCCUPIED_TIME  \
# 0  FILLMORE ST       22.0     61200.0              35847.0
# 1  FILLMORE ST       24.0     64800.0              27576.0
# 2   JACKSON ST        1.0     79200.0              39985.0
# 3   JACKSON ST        2.0     82800.0              30465.0
# 4     09TH AVE        3.0     93600.0              85690.0
#
#           START_TIME_DT
# 0  01-jul-2012 21:00:00
# 1  01-jul-2012 22:00:00
# 2  01-jul-2012 02:00:00
# 3  01-jul-2012 08:00:00
# 4  01-jul-2012 08:00:00

# %%
#provide compatible names with train data
sensorData.STREET_NAME = sensorData.STREET_NAME.str.lower()
sensorData.STREET_NAME = sensorData.STREET_NAME.str.capitalize() # make sure it captures Van Ness Avenue
sensorData.STREET_NAME = sensorData.STREET_NAME.str.replace('st$', 'Street')
sensorData.STREET_NAME = sensorData.STREET_NAME.str.replace('ave$', 'Avenue')
sensorData.STREET_NAME = sensorData.STREET_NAME.str.replace('Van ness Avenue', 'Van Ness Avenue')

# %%
sensorData = sensorData.dropna(axis=0, how='all')

# %%
sensorData['Street_Block'] = sensorData.STREET_NAME + '_' + sensorData.BLOCK_NUM.astype(int).astype(str)
sensorData = sensorData[sensorData.Street_Block.isin(np.array(Blocks.Street_Block))]
sensorData.drop(['STREET_NAME', 'BLOCK_NUM'], axis=1, inplace=True)

# %%
sensorData.head()
# Out:
#     TOTAL_TIME  TOTAL_OCCUPIED_TIME         START_TIME_DT      Street_Block
# 44     43200.0              32400.0  01-jul-2012 16:00:00   Kearny Street_2
# 58     90000.0              69215.0  01-jul-2012 18:00:00    23rd Street_33
# 59     64800.0              13743.0  01-jul-2012 08:00:00  Battery Street_2
# 73    234000.0             165345.0  01-jul-2012 16:00:00    Grove Street_0
# 74    234000.0              76776.0  01-jul-2012 19:00:00    Grove Street_0

# %%
sensorData.shape
# Out:
# (425635, 4)

# %%
sensorData.reset_index(drop = True, inplace=True)
sensorData.to_feather('new_sensor_data')

# %%
sensorData = pd.read_feather('new_sensor_data')

# %%
sensorData['Available_Spots'] = np.floor((sensorData['TOTAL_TIME'] - sensorData['TOTAL_OCCUPIED_TIME'])/3600)

# %%
sensorData.START_TIME_DT = pd.to_datetime(sensorData.START_TIME_DT)

# %%
sensorData['Dayofweek'] = sensorData.START_TIME_DT.dt.dayofweek
sensorData['month'] = sensorData.START_TIME_DT.dt.month
sensorData['hour'] = sensorData.START_TIME_DT.dt.hour
sensorData['year'] = sensorData.START_TIME_DT.dt.year
sensorData.drop(['TOTAL_TIME', 'TOTAL_OCCUPIED_TIME','START_TIME_DT'], axis =1, inplace=True)

# %%
sensorData.shape
# Out:
# (425635, 6)

# %%
sensorData = sensorData.merge(intersections, on = 'Street_Block')
sensorData.shape
# Out:
# (568922, 9)

# %%
sensorData = sensorData.merge(Blocks, on = 'Street_Block')

# %%
#adjust for the fact that block will have at least two street segments
sensorData['Available_Spots'] = np.floor(sensorData['Available_Spots'] / (2*sensorData['count']))

# %%
sensorData.to_feather('new_sensor_data2')

# %%
sensorData = pd.read_feather('new_sensor_data2')

# %%
sensorData.head()
# Out:
#       Street_Block  Available_Spots  Dayofweek  month  hour  year        lat  \
# 0  Kearny Street_2              1.0          6      7    16  2012  37.790518
# 1  Kearny Street_2              4.0          6      7    20  2012  37.790518
# 2  Kearny Street_2              5.0          6      7     5  2012  37.790518
# 3  Kearny Street_2              4.0          6      7    21  2012  37.790518
# 4  Kearny Street_2              5.0          1      7     6  2012  37.790518
#
#           lng  street_id  count
# 0 -122.404027         27      1
# 1 -122.404027         27      1
# 2 -122.404027         27      1
# 3 -122.404027         27      1
# 4 -122.404027         27      1

# %%
sensorData.shape
# Out:
# (568922, 10)
